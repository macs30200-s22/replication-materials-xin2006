# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import csv

# %% [markdown]
# # Part 1: Crime data Process

# %% [markdown]
# ## Import the original crime data

# %% [markdown]
# Since the dataset is too large, they are imported as two seperate file and then be merged together

# %%
# Crime data from 01/2015 to 12/2017
crime_15_17 = pd.read_csv(r'Crimes2015_17.csv')

# %%
crime_15_17
# Out:
#               ID Case Number                    Date  \
# 0       10225520    HY412735  01/01/2015 12:00:00 AM
# 1       11028448    JA360336  01/01/2015 12:00:00 AM
# 2       10225760    HY412902  01/01/2015 12:00:00 AM
# 3       11242929    JB168310  01/01/2015 12:00:00 AM
# 4       10229179    HY416572  01/01/2015 12:00:00 AM
# ...          ...         ...                     ...
# 803280  11192239    JB100032  12/31/2017 11:45:00 PM
# 803281  11192254    JB100003  12/31/2017 11:45:00 PM
# 803282  11192540    JB100551  12/31/2017 11:48:00 PM
# 803283  11196379    JB105867  12/31/2017 11:50:00 PM
# 803284  11192233    JB100016  12/31/2017 11:58:00 PM
#
#                             Block  IUCR                Primary Type  \
# 0          075XX S BLACKSTONE AVE  1153          DECEPTIVE PRACTICE
# 1                051XX W HURON ST  0281         CRIM SEXUAL ASSAULT
# 2               050XX N MARINE DR  0810                       THEFT
# 3       049XX S COTTAGE GROVE AVE  1153          DECEPTIVE PRACTICE
# 4           039XX S LAKE PARK AVE  1752  OFFENSE INVOLVING CHILDREN
# ...                           ...   ...                         ...
# 803280           019XX S CANAL ST  1320             CRIMINAL DAMAGE
# 803281           115XX S STATE ST  041A                     BATTERY
# 803282        001XX E SUPERIOR ST  0890                       THEFT
# 803283   024XX N LAKE SHORE DR NB  0460                     BATTERY
# 803284       046XX N ST LOUIS AVE  0630                    BURGLARY
#
#                                 Description Location Description  Arrest  \
# 0       FINANCIAL IDENTITY THEFT OVER $ 300            RESIDENCE   False
# 1                            NON-AGGRAVATED            APARTMENT    True
# 2                                 OVER $500            APARTMENT   False
# 3       FINANCIAL IDENTITY THEFT OVER $ 300            APARTMENT   False
# 4             AGG CRIM SEX ABUSE FAM MEMBER            RESIDENCE   False
# ...                                     ...                  ...     ...
# 803280                           TO VEHICLE               STREET   False
# 803281                  AGGRAVATED: HANDGUN            RESIDENCE   False
# 803282                        FROM BUILDING          HOTEL/MOTEL   False
# 803283                               SIMPLE  MOVIE HOUSE/THEATER   False
# 803284               ATTEMPT FORCIBLE ENTRY            APARTMENT   False
#
#         Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0          False  ...   5.0              43        11     1187511.0
# 1           True  ...  37.0              25        02           NaN
# 2          False  ...  48.0               3        06     1169650.0
# 3          False  ...   4.0              39        11           NaN
# 4          False  ...   4.0              36        20     1183388.0
# ...          ...  ...   ...             ...       ...           ...
# 803280      True  ...  25.0              31        14     1173432.0
# 803281      True  ...  34.0              53       04B     1178329.0
# 803282     False  ...  42.0               8        06     1177508.0
# 803283     False  ...  43.0               7       08B     1175293.0
# 803284     False  ...  33.0              14        05     1152214.0
#
#        Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0         1855334.0  2015  02/10/2018 03:50:01 PM  41.758131 -87.588352
# 1               NaN  2015  09/02/2019 03:57:18 PM        NaN        NaN
# 2         1934124.0  2015  02/10/2018 03:50:01 PM  41.974743 -87.651517
# 3               NaN  2015  03/01/2018 03:54:55 PM        NaN        NaN
# 4         1878984.0  2015  02/10/2018 03:50:01 PM  41.823126 -87.602726
# ...             ...   ...                     ...        ...        ...
# 803280    1891037.0  2017  05/04/2018 03:51:04 PM  41.856427 -87.638893
# 803281    1828012.0  2017  05/04/2018 03:51:04 PM  41.683369 -87.622830
# 803282    1905401.0  2017  05/04/2018 03:51:04 PM  41.895751 -87.623496
# 803283    1916610.0  2017  05/04/2018 03:51:04 PM  41.926559 -87.631294
# 803284    1930694.0  2017  05/04/2018 03:51:04 PM  41.965694 -87.715726
#
#                              Location
# 0       (41.758131167, -87.588352326)
# 1                                 NaN
# 2       (41.974742888, -87.651517395)
# 3                                 NaN
# 4       (41.823125769, -87.602725951)
# ...                               ...
# 803280  (41.856426716, -87.638892854)
# 803281  (41.683369303, -87.622829524)
# 803282  (41.895750913, -87.623495923)
# 803283  (41.926558908, -87.631294073)
# 803284  (41.965693651, -87.715726125)
#
# [803285 rows x 22 columns]

# %%
# Crime data from 01/2018 to 04/2022
crime_18_22 = pd.read_excel(r'Crimes_2018_2022.4.xlsx')

# %%
crime_18_22
# Out:
#                ID Case Number                    Date                  Block  \
# 0        12137388    JD334537  01/01/2018 12:00:00 AM    010XX W NEWPORT AVE
# 1        11196173    JB105519  01/01/2018 12:00:00 AM   075XX S ST LOUIS AVE
# 2        11198738    JB108247  01/01/2018 12:00:00 AM    0000X S COLUMBUS DR
# 3        11212228    JB127156  01/01/2018 12:00:00 AM     109XX S HALSTED ST
# 4        11220328    JB137687  01/01/2018 12:00:00 AM      038XX N DRAKE AVE
# ...           ...         ...                     ...                    ...
# 1000015  12665837    JF202108  04/08/2022 11:38:00 PM        033XX W 54TH ST
# 1000016     26697    JF202059  04/08/2022 11:39:00 PM        020XX W 35TH ST
# 1000017  12665852    JF202129  04/08/2022 11:40:00 PM  044XX N CLARENDON AVE
# 1000018  12665907    JF202148  04/08/2022 11:52:00 PM     059XX S RACINE AVE
# 1000019  12665982    JF202150  04/08/2022 11:52:00 PM     059XX S RACINE AVE
#
#          IUCR                Primary Type  \
# 0        1153          DECEPTIVE PRACTICE
# 1        1152          DECEPTIVE PRACTICE
# 2         820                       THEFT
# 3         810                       THEFT
# 4        1750  OFFENSE INVOLVING CHILDREN
# ...       ...                         ...
# 1000015  1310             CRIMINAL DAMAGE
# 1000016   110                    HOMICIDE
# 1000017   486                     BATTERY
# 1000018  5111               OTHER OFFENSE
# 1000019  1812                   NARCOTICS
#
#                                    Description  \
# 0          FINANCIAL IDENTITY THEFT OVER $ 300
# 1                        ILLEGAL USE CASH CARD
# 2                               $500 AND UNDER
# 3                                    OVER $500
# 4                                  CHILD ABUSE
# ...                                        ...
# 1000015                            TO PROPERTY
# 1000016                    FIRST DEGREE MURDER
# 1000017                DOMESTIC BATTERY SIMPLE
# 1000018     GUN OFFENDER - ANNUAL REGISTRATION
# 1000019  POSSESS - CANNABIS MORE THAN 30 GRAMS
#
#                    Location Description  Arrest  Domestic  ...  Ward  \
# 0                       OTHER (SPECIFY)   False     False  ...  44.0
# 1                             RESIDENCE   False     False  ...  18.0
# 2        PARKING LOT/GARAGE(NON.RESID.)   False     False  ...  42.0
# 3          NURSING HOME/RETIREMENT HOME   False     False  ...  34.0
# 4                             RESIDENCE    True      True  ...  35.0
# ...                                 ...     ...       ...  ...   ...
# 1000015                       RESIDENCE    True     False  ...  14.0
# 1000016                          STREET   False     False  ...  12.0
# 1000017                       APARTMENT   False      True  ...  46.0
# 1000018                          STREET    True     False  ...  16.0
# 1000019                          STREET    True     False  ...  16.0
#
#          Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0                   6.0        11           NaN          NaN  2018
# 1                  70.0        11     1154348.0    1854412.0  2018
# 2                  32.0         6     1178293.0    1900315.0  2018
# 3                  49.0         6     1172930.0    1832289.0  2018
# 4                  16.0        20     1152042.0    1925257.0  2018
# ...                 ...       ...           ...          ...   ...
# 1000015            63.0        14     1154847.0    1868611.0  2022
# 1000016            59.0       01A     1163176.0    1881462.0  2022
# 1000017             3.0       08B     1170120.0    1929591.0  2022
# 1000018            67.0        26     1169337.0    1865408.0  2022
# 1000019            67.0        18     1169337.0    1865408.0  2022
#
#                      Updated On   Latitude  Longitude  \
# 0        08/17/2020 03:50:01 PM        NaN        NaN
# 1        05/04/2018 03:51:04 PM  41.756325 -87.709916
# 2        05/04/2018 03:51:04 PM  41.881777 -87.620768
# 3        05/04/2018 03:51:04 PM  41.695227 -87.642468
# 4        05/04/2018 03:51:04 PM  41.950778 -87.716502
# ...                         ...        ...        ...
# 1000015  04/15/2022 04:49:50 PM  41.795279 -87.707709
# 1000016  04/15/2022 04:49:50 PM  41.830373 -87.676806
# 1000017  04/15/2022 04:49:50 PM  41.962294 -87.649922
# 1000018  04/15/2022 04:49:50 PM  41.786188 -87.654667
# 1000019  04/15/2022 04:49:50 PM  41.786188 -87.654667
#
#                               Location
# 0                                  NaN
# 1        (41.756324845, -87.709916401)
# 2        (41.881776822, -87.620767948)
# 3         (41.69522655, -87.642467755)
# 4        (41.950777548, -87.716502434)
# ...                                ...
# 1000015  (41.795279122, -87.707709087)
# 1000016  (41.830373381, -87.676806309)
# 1000017  (41.962293932, -87.649922035)
# 1000018  (41.786188054, -87.654666603)
# 1000019  (41.786188054, -87.654666603)
#
# [1000020 rows x 22 columns]

# %%
# Merge the two data frame
crime_df = crime_15_17.append(crime_18_22, ignore_index=True)

# %%
crime_df
# Out:
#                ID Case Number                    Date  \
# 0        10225520    HY412735  01/01/2015 12:00:00 AM
# 1        11028448    JA360336  01/01/2015 12:00:00 AM
# 2        10225760    HY412902  01/01/2015 12:00:00 AM
# 3        11242929    JB168310  01/01/2015 12:00:00 AM
# 4        10229179    HY416572  01/01/2015 12:00:00 AM
# ...           ...         ...                     ...
# 1803300  12665837    JF202108  04/08/2022 11:38:00 PM
# 1803301     26697    JF202059  04/08/2022 11:39:00 PM
# 1803302  12665852    JF202129  04/08/2022 11:40:00 PM
# 1803303  12665907    JF202148  04/08/2022 11:52:00 PM
# 1803304  12665982    JF202150  04/08/2022 11:52:00 PM
#
#                              Block  IUCR                Primary Type  \
# 0           075XX S BLACKSTONE AVE  1153          DECEPTIVE PRACTICE
# 1                 051XX W HURON ST  0281         CRIM SEXUAL ASSAULT
# 2                050XX N MARINE DR  0810                       THEFT
# 3        049XX S COTTAGE GROVE AVE  1153          DECEPTIVE PRACTICE
# 4            039XX S LAKE PARK AVE  1752  OFFENSE INVOLVING CHILDREN
# ...                            ...   ...                         ...
# 1803300            033XX W 54TH ST  1310             CRIMINAL DAMAGE
# 1803301            020XX W 35TH ST   110                    HOMICIDE
# 1803302      044XX N CLARENDON AVE   486                     BATTERY
# 1803303         059XX S RACINE AVE  5111               OTHER OFFENSE
# 1803304         059XX S RACINE AVE  1812                   NARCOTICS
#
#                                    Description Location Description  Arrest  \
# 0          FINANCIAL IDENTITY THEFT OVER $ 300            RESIDENCE   False
# 1                               NON-AGGRAVATED            APARTMENT    True
# 2                                    OVER $500            APARTMENT   False
# 3          FINANCIAL IDENTITY THEFT OVER $ 300            APARTMENT   False
# 4                AGG CRIM SEX ABUSE FAM MEMBER            RESIDENCE   False
# ...                                        ...                  ...     ...
# 1803300                            TO PROPERTY            RESIDENCE    True
# 1803301                    FIRST DEGREE MURDER               STREET   False
# 1803302                DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 1803303     GUN OFFENDER - ANNUAL REGISTRATION               STREET    True
# 1803304  POSSESS - CANNABIS MORE THAN 30 GRAMS               STREET    True
#
#          Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0           False  ...   5.0            43.0        11     1187511.0
# 1            True  ...  37.0            25.0        02           NaN
# 2           False  ...  48.0             3.0        06     1169650.0
# 3           False  ...   4.0            39.0        11           NaN
# 4           False  ...   4.0            36.0        20     1183388.0
# ...           ...  ...   ...             ...       ...           ...
# 1803300     False  ...  14.0            63.0        14     1154847.0
# 1803301     False  ...  12.0            59.0       01A     1163176.0
# 1803302      True  ...  46.0             3.0       08B     1170120.0
# 1803303     False  ...  16.0            67.0        26     1169337.0
# 1803304     False  ...  16.0            67.0        18     1169337.0
#
#         Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0          1855334.0  2015  02/10/2018 03:50:01 PM  41.758131 -87.588352
# 1                NaN  2015  09/02/2019 03:57:18 PM        NaN        NaN
# 2          1934124.0  2015  02/10/2018 03:50:01 PM  41.974743 -87.651517
# 3                NaN  2015  03/01/2018 03:54:55 PM        NaN        NaN
# 4          1878984.0  2015  02/10/2018 03:50:01 PM  41.823126 -87.602726
# ...              ...   ...                     ...        ...        ...
# 1803300    1868611.0  2022  04/15/2022 04:49:50 PM  41.795279 -87.707709
# 1803301    1881462.0  2022  04/15/2022 04:49:50 PM  41.830373 -87.676806
# 1803302    1929591.0  2022  04/15/2022 04:49:50 PM  41.962294 -87.649922
# 1803303    1865408.0  2022  04/15/2022 04:49:50 PM  41.786188 -87.654667
# 1803304    1865408.0  2022  04/15/2022 04:49:50 PM  41.786188 -87.654667
#
#                               Location
# 0        (41.758131167, -87.588352326)
# 1                                  NaN
# 2        (41.974742888, -87.651517395)
# 3                                  NaN
# 4        (41.823125769, -87.602725951)
# ...                                ...
# 1803300  (41.795279122, -87.707709087)
# 1803301  (41.830373381, -87.676806309)
# 1803302  (41.962293932, -87.649922035)
# 1803303  (41.786188054, -87.654666603)
# 1803304  (41.786188054, -87.654666603)
#
# [1803305 rows x 22 columns]

# %%
crime_df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %% [markdown]
# ## Clean the crime data
# 1) Drop uncessary columns
# 2) Set the data of data as "Month/Year" format for later use.

# %%
crime=crime_df.drop(['ID','Case Number','Block', 'IUCR','Description','Location Description','Arrest','Beat','Ward','FBI Code',
               'X Coordinate','Y Coordinate','Updated On', 
               'Latitude', 'Longitude','Location'],axis=1)

# %%
# crime_2022=crime[crime['Year']==2022]
# crime_2022.to_csv(r'crime_2022.csv')

# %%
crime['Month'] = crime_df.Date.str.extract(pat='(^[0-9][0-9])', expand=False)
crime.Month
# Out:
# 0          01
# 1          01
# 2          01
# 3          01
# 4          01
#            ..
# 1803300    04
# 1803301    04
# 1803302    04
# 1803303    04
# 1803304    04
# Name: Month, Length: 1803305, dtype: object

# %%
crime['Year']=crime['Year'].map(lambda x:str(x))

# %%
crime['Month_Year']=crime['Month'].str.cat(crime['Year'],sep="/")

# %%
crime['Date'] = crime_df.Date.str.extract(pat='(^[0-9][0-9][/][0-9][0-9][/][0-9][0-9][0-9][0-9])', expand=False)

# %%
crime.head()
# Out:
#          Date                Primary Type  Domestic  District  Community Area  \
# 0  01/01/2015          DECEPTIVE PRACTICE     False       4.0            43.0
# 1  01/01/2015         CRIM SEXUAL ASSAULT      True      15.0            25.0
# 2  01/01/2015                       THEFT     False      20.0             3.0
# 3  01/01/2015          DECEPTIVE PRACTICE     False       2.0            39.0
# 4  01/01/2015  OFFENSE INVOLVING CHILDREN     False       2.0            36.0
#
#    Year Month Month_Year
# 0  2015    01    01/2015
# 1  2015    01    01/2015
# 2  2015    01    01/2015
# 3  2015    01    01/2015
# 4  2015    01    01/2015

# %%
crime=crime.drop(['Year','Month'],axis=1)

# %%
#Since the data for April 2022 is not complete, this month would be dropped.
crime=crime.drop(crime[(crime['Month_Year']=='04/2022')].index)

# %%
crime.tail()
# Out:
#                Date       Primary Type  Domestic  District  Community Area  \
# 1798993  03/31/2022            BATTERY      True       9.0            60.0
# 1798994  03/31/2022           BURGLARY     False       6.0            69.0
# 1798995  03/31/2022            ASSAULT      True       2.0            35.0
# 1798996  03/31/2022  WEAPONS VIOLATION     False      10.0            30.0
# 1798997  03/31/2022            BATTERY      True      16.0            15.0
#
#         Month_Year
# 1798993    03/2022
# 1798994    03/2022
# 1798995    03/2022
# 1798996    03/2022
# 1798997    03/2022

# %%
len(crime)
# Out:
# 1798998

# %% [markdown]
# ## Group the type of crime
# Up to now, we have cleaned the crime data from 01/2010 to 04/2022, and we are going to group the crime type and count the number of crime for each type to obeserve the change of pattern.

# %%
type_set=set()
for i in crime['Primary Type']:
    type_set.add(i)
type_set
# Out:
# {'ARSON',
#  'ASSAULT',
#  'BATTERY',
#  'BURGLARY',
#  'CONCEALED CARRY LICENSE VIOLATION',
#  'CRIM SEXUAL ASSAULT',
#  'CRIMINAL DAMAGE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'CRIMINAL TRESPASS',
#  'DECEPTIVE PRACTICE',
#  'GAMBLING',
#  'HOMICIDE',
#  'HUMAN TRAFFICKING',
#  'INTERFERENCE WITH PUBLIC OFFICER',
#  'INTIMIDATION',
#  'KIDNAPPING',
#  'LIQUOR LAW VIOLATION',
#  'MOTOR VEHICLE THEFT',
#  'NARCOTICS',
#  'NON - CRIMINAL',
#  'NON-CRIMINAL',
#  'NON-CRIMINAL (SUBJECT SPECIFIED)',
#  'OBSCENITY',
#  'OFFENSE INVOLVING CHILDREN',
#  'OTHER NARCOTIC VIOLATION',
#  'OTHER OFFENSE',
#  'PROSTITUTION',
#  'PUBLIC INDECENCY',
#  'PUBLIC PEACE VIOLATION',
#  'RITUALISM',
#  'ROBBERY',
#  'SEX OFFENSE',
#  'STALKING',
#  'THEFT',
#  'WEAPONS VIOLATION'}

# %% [markdown]
# ## Classification 1:
#
# ### 1) Crime against persons:
# 'ASSAULT', 'BATTERY', 'CRIM SEXUAL ASSAULT', 'CRIMINAL SEXUAL ASSAULT', 'CRIMINAL TRESPASS', 'HOMICIDE', 'INTIMIDATION', 'OTHER OFFENSE', 'STALKING','SEX OFFENSE'.
#
# ### 2) Crime against property:
# 'BURGLARY', 'CRIMINAL DAMAGE','HUMAN TRAFFICKING', 'KIDNAPPING','MOTOR VEHICLE THEFT', 'THEFT', 'ROBBERY'.
#
# ### 3) Online Crime (which is expected to be a special type in the context of COVID-19):
# 'DECEPTIVE PRACTICE'
#
# ## Classification 2:
#
# 1)  Domestic Crime
# 2)  Non-domestic Crime

# %%
# Count for domestic crime
count_domestic={}
for i in range(len(crime)):
    if crime['Domestic'][i]==True:
        if crime['Month_Year'][i] not in count_domestic:
            count_domestic[crime['Month_Year'][i]]=0
        count_domestic[crime['Month_Year'][i]]+=1

count_domestic
# Out:
# {'01/2015': 3281,
#  '02/2015': 2578,
#  '03/2015': 3462,
#  '04/2015': 3593,
#  '05/2015': 4035,
#  '06/2015': 3826,
#  '07/2015': 3947,
#  '08/2015': 3889,
#  '09/2015': 3557,
#  '10/2015': 3258,
#  '11/2015': 3139,
#  '12/2015': 3367,
#  '01/2016': 3315,
#  '02/2016': 3065,
#  '03/2016': 3656,
#  '04/2016': 3555,
#  '05/2016': 3965,
#  '06/2016': 4116,
#  '07/2016': 4013,
#  '08/2016': 4000,
#  '09/2016': 3553,
#  '10/2016': 3507,
#  '11/2016': 3269,
#  '12/2016': 3201,
#  '01/2017': 3410,
#  '02/2017': 2978,
#  '03/2017': 3395,
#  '04/2017': 3675,
#  '05/2017': 3858,
#  '06/2017': 3933,
#  '07/2017': 4100,
#  '08/2017': 3870,
#  '09/2017': 3611,
#  '10/2017': 3447,
#  '11/2017': 3254,
#  '12/2017': 3332,
#  '01/2018': 3313,
#  '02/2018': 2891,
#  '03/2018': 3555,
#  '04/2018': 3510,
#  '05/2018': 4291,
#  '06/2018': 4134,
#  '07/2018': 4147,
#  '08/2018': 4006,
#  '09/2018': 3650,
#  '10/2018': 3637,
#  '11/2018': 3379,
#  '12/2018': 3529,
#  '01/2019': 3367,
#  '02/2019': 3038,
#  '03/2019': 3518,
#  '04/2019': 3545,
#  '05/2019': 4086,
#  '06/2019': 3962,
#  '07/2019': 4119,
#  '08/2019': 3947,
#  '09/2019': 3635,
#  '10/2019': 3347,
#  '11/2019': 3303,
#  '12/2019': 3402,
#  '01/2020': 3288,
#  '02/2020': 3042,
#  '03/2020': 3343,
#  '04/2020': 2709,
#  '05/2020': 3247,
#  '06/2020': 3715,
#  '07/2020': 3940,
#  '08/2020': 3793,
#  '09/2020': 3310,
#  '10/2020': 3210,
#  '11/2020': 3116,
#  '12/2020': 3187,
#  '01/2021': 3419,
#  '02/2021': 2841,
#  '03/2021': 3631,
#  '04/2021': 3739,
#  '05/2021': 4223,
#  '06/2021': 4233,
#  '07/2021': 4125,
#  '08/2021': 4060,
#  '09/2021': 3881,
#  '10/2021': 3718,
#  '11/2021': 3369,
#  '12/2021': 3555,
#  '01/2022': 3132,
#  '02/2022': 2884,
#  '03/2022': 3439}

# %%
# Count for non-domestic crime
count_nondomestic={}
for i in range(len(crime)):
    if crime['Domestic'][i]==False:
        if crime['Month_Year'][i] not in count_nondomestic:
            count_nondomestic[crime['Month_Year'][i]]=0
        count_nondomestic[crime['Month_Year'][i]]+=1

count_nondomestic
# Out:
# {'01/2015': 17664,
#  '02/2015': 13821,
#  '03/2015': 18220,
#  '04/2015': 18134,
#  '05/2015': 19673,
#  '06/2015': 19357,
#  '07/2015': 20285,
#  '08/2015': 20929,
#  '09/2015': 19568,
#  '10/2015': 19837,
#  '11/2015': 17452,
#  '12/2015': 17779,
#  '01/2016': 17437,
#  '02/2016': 15678,
#  '03/2016': 18396,
#  '04/2016': 17615,
#  '05/2016': 19582,
#  '06/2016': 19957,
#  '07/2016': 20843,
#  '08/2016': 20918,
#  '09/2016': 20140,
#  '10/2016': 20249,
#  '11/2016': 18477,
#  '12/2016': 17190,
#  '01/2017': 18726,
#  '02/2017': 16335,
#  '03/2017': 17174,
#  '04/2017': 18021,
#  '05/2017': 19525,
#  '06/2017': 19933,
#  '07/2017': 20773,
#  '08/2017': 20864,
#  '09/2017': 19235,
#  '10/2017': 19472,
#  '11/2017': 18248,
#  '12/2017': 17768,
#  '01/2018': 17214,
#  '02/2018': 14462,
#  '03/2018': 17677,
#  '04/2018': 17633,
#  '05/2018': 20445,
#  '06/2018': 20109,
#  '07/2018': 21120,
#  '08/2018': 21457,
#  '09/2018': 19453,
#  '10/2018': 19205,
#  '11/2018': 17304,
#  '12/2018': 18463,
#  '01/2019': 16338,
#  '02/2019': 15386,
#  '03/2019': 16918,
#  '04/2019': 17479,
#  '05/2019': 19568,
#  '06/2019': 19647,
#  '07/2019': 20740,
#  '08/2019': 20462,
#  '09/2019': 18810,
#  '10/2019': 18346,
#  '11/2019': 16648,
#  '12/2019': 17385,
#  '01/2020': 16576,
#  '02/2020': 15131,
#  '03/2020': 13375,
#  '04/2020': 10181,
#  '05/2020': 14327,
#  '06/2020': 13891,
#  '07/2020': 15655,
#  '08/2020': 16081,
#  '09/2020': 14595,
#  '10/2020': 15199,
#  '11/2020': 13486,
#  '12/2020': 13270,
#  '01/2021': 12664,
#  '02/2021': 10195,
#  '03/2021': 12291,
#  '04/2021': 11661,
#  '05/2021': 13425,
#  '06/2021': 14432,
#  '07/2021': 14940,
#  '08/2021': 14264,
#  '09/2021': 15211,
#  '10/2021': 15477,
#  '11/2021': 13879,
#  '12/2021': 13561,
#  '01/2022': 12086,
#  '02/2022': 11972,
#  '03/2022': 14159}

# %%
# Count for crime against persons
crime_persons=['ASSAULT', 'BATTERY', 'CRIM SEXUAL ASSAULT', 
               'CRIMINAL SEXUAL ASSAULT', 'CRIMINAL TRESPASS', 'HOMICIDE', 
               'INTIMIDATION', 'OTHER OFFENSE', 'STALKING','SEX OFFENSE' ]
count_persons={}
for i in range(len(crime)):
    if crime['Primary Type'][i] in crime_persons:
        if crime['Month_Year'][i] not in count_persons:
            count_persons[crime['Month_Year'][i]]=0
        count_persons[crime['Month_Year'][i]]+=1

count_persons
# Out:
# {'01/2015': 7135,
#  '02/2015': 5825,
#  '03/2015': 7889,
#  '04/2015': 7799,
#  '05/2015': 9088,
#  '06/2015': 8586,
#  '07/2015': 8580,
#  '08/2015': 8734,
#  '09/2015': 8021,
#  '10/2015': 7773,
#  '11/2015': 6850,
#  '12/2015': 6897,
#  '01/2016': 7087,
#  '02/2016': 6740,
#  '03/2016': 8266,
#  '04/2016': 7715,
#  '05/2016': 8993,
#  '06/2016': 9141,
#  '07/2016': 8851,
#  '08/2016': 8803,
#  '09/2016': 8280,
#  '10/2016': 8399,
#  '11/2016': 7325,
#  '12/2016': 6800,
#  '01/2017': 7424,
#  '02/2017': 6908,
#  '03/2017': 7680,
#  '04/2017': 8181,
#  '05/2017': 8987,
#  '06/2017': 8873,
#  '07/2017': 9054,
#  '08/2017': 8549,
#  '09/2017': 8324,
#  '10/2017': 8026,
#  '11/2017': 7288,
#  '12/2017': 7065,
#  '01/2018': 7192,
#  '02/2018': 6624,
#  '03/2018': 7903,
#  '04/2018': 7810,
#  '05/2018': 9589,
#  '06/2018': 8969,
#  '07/2018': 9364,
#  '08/2018': 8942,
#  '09/2018': 8461,
#  '10/2018': 8332,
#  '11/2018': 7422,
#  '12/2018': 7643,
#  '01/2019': 7291,
#  '02/2019': 6945,
#  '03/2019': 7996,
#  '04/2019': 8017,
#  '05/2019': 9375,
#  '06/2019': 9143,
#  '07/2019': 9297,
#  '08/2019': 8680,
#  '09/2019': 8454,
#  '10/2019': 7870,
#  '11/2019': 7182,
#  '12/2019': 7360,
#  '01/2020': 7424,
#  '02/2020': 6828,
#  '03/2020': 6791,
#  '04/2020': 4975,
#  '05/2020': 6406,
#  '06/2020': 7222,
#  '07/2020': 7824,
#  '08/2020': 7653,
#  '09/2020': 6850,
#  '10/2020': 6597,
#  '11/2020': 5824,
#  '12/2020': 5416,
#  '01/2021': 5643,
#  '02/2021': 5107,
#  '03/2021': 6270,
#  '04/2021': 6419,
#  '05/2021': 7439,
#  '06/2021': 7805,
#  '07/2021': 7767,
#  '08/2021': 7422,
#  '09/2021': 7731,
#  '10/2021': 7481,
#  '11/2021': 6391,
#  '12/2021': 6328,
#  '01/2022': 5710,
#  '02/2022': 5759,
#  '03/2022': 6906}

# %%
# Count for crime against property
crime_property=['BURGLARY', 'CRIMINAL DAMAGE','HUMAN TRAFFICKING', 
               'KIDNAPPING','MOTOR VEHICLE THEFT', 'THEFT', 'ROBBERY']
count_property={}
for i in range(len(crime)):
    if crime['Primary Type'][i] in crime_property:
        if crime['Month_Year'][i] not in count_property:
            count_property[crime['Month_Year'][i]]=0
        count_property[crime['Month_Year'][i]]+=1

count_property
# Out:
# {'01/2015': 9038,
#  '02/2015': 6492,
#  '03/2015': 8779,
#  '04/2015': 9332,
#  '05/2015': 10211,
#  '06/2015': 10295,
#  '07/2015': 11201,
#  '08/2015': 11482,
#  '09/2015': 10691,
#  '10/2015': 10864,
#  '11/2015': 9874,
#  '12/2015': 10857,
#  '01/2016': 10089,
#  '02/2016': 8485,
#  '03/2016': 9829,
#  '04/2016': 9480,
#  '05/2016': 10685,
#  '06/2016': 10942,
#  '07/2016': 12339,
#  '08/2016': 12642,
#  '09/2016': 11984,
#  '10/2016': 11970,
#  '11/2016': 11407,
#  '12/2016': 10531,
#  '01/2017': 10910,
#  '02/2017': 9137,
#  '03/2017': 9276,
#  '04/2017': 9925,
#  '05/2017': 10671,
#  '06/2017': 11475,
#  '07/2017': 12059,
#  '08/2017': 12440,
#  '09/2017': 10920,
#  '10/2017': 11487,
#  '11/2017': 10881,
#  '12/2017': 10702,
#  '01/2018': 9660,
#  '02/2018': 7546,
#  '03/2018': 9400,
#  '04/2018': 9636,
#  '05/2018': 11033,
#  '06/2018': 11383,
#  '07/2018': 11778,
#  '08/2018': 12263,
#  '09/2018': 10813,
#  '10/2018': 10833,
#  '11/2018': 9664,
#  '12/2018': 10686,
#  '01/2019': 8525,
#  '02/2019': 7945,
#  '03/2019': 8427,
#  '04/2019': 9011,
#  '05/2019': 10127,
#  '06/2019': 10531,
#  '07/2019': 11204,
#  '08/2019': 11268,
#  '09/2019': 10072,
#  '10/2019': 9995,
#  '11/2019': 9042,
#  '12/2019': 9800,
#  '01/2020': 8541,
#  '02/2020': 7840,
#  '03/2020': 7122,
#  '04/2020': 5932,
#  '05/2020': 8154,
#  '06/2020': 7663,
#  '07/2020': 8610,
#  '08/2020': 9131,
#  '09/2020': 8079,
#  '10/2020': 7973,
#  '11/2020': 7165,
#  '12/2020': 6614,
#  '01/2021': 6409,
#  '02/2021': 5041,
#  '03/2021': 6302,
#  '04/2021': 6342,
#  '05/2021': 7283,
#  '06/2021': 7756,
#  '07/2021': 8547,
#  '08/2021': 8369,
#  '09/2021': 8697,
#  '10/2021': 9209,
#  '11/2021': 8480,
#  '12/2021': 8532,
#  '01/2022': 7390,
#  '02/2022': 6878,
#  '03/2022': 8221}

# %%
# Count for deceptive crime
count_deceptive={}
for i in range(len(crime)):
    if crime['Primary Type'][i] == 'DECEPTIVE PRACTICE':
        if crime['Month_Year'][i] not in count_deceptive:
            count_deceptive[crime['Month_Year'][i]]=0
        count_deceptive[crime['Month_Year'][i]]+=1

count_deceptive
# Out:
# {'01/2015': 1344,
#  '02/2015': 1325,
#  '03/2015': 1447,
#  '04/2015': 1491,
#  '05/2015': 1323,
#  '06/2015': 1309,
#  '07/2015': 1389,
#  '08/2015': 1384,
#  '09/2015': 1344,
#  '10/2015': 1376,
#  '11/2015': 1263,
#  '12/2015': 1401,
#  '01/2016': 1647,
#  '02/2016': 1530,
#  '03/2016': 1588,
#  '04/2016': 1570,
#  '05/2016': 1476,
#  '06/2016': 1702,
#  '07/2016': 1528,
#  '08/2016': 1706,
#  '09/2016': 1624,
#  '10/2016': 1710,
#  '11/2016': 1489,
#  '12/2016': 1716,
#  '01/2017': 1807,
#  '02/2017': 1531,
#  '03/2017': 1647,
#  '04/2017': 1555,
#  '05/2017': 1562,
#  '06/2017': 1605,
#  '07/2017': 1642,
#  '08/2017': 1651,
#  '09/2017': 1642,
#  '10/2017': 1637,
#  '11/2017': 1577,
#  '12/2017': 1736,
#  '01/2018': 1638,
#  '02/2018': 1486,
#  '03/2018': 1698,
#  '04/2018': 1600,
#  '05/2018': 1726,
#  '06/2018': 1661,
#  '07/2018': 1757,
#  '08/2018': 1784,
#  '09/2018': 1568,
#  '10/2018': 1600,
#  '11/2018': 1504,
#  '12/2018': 1680,
#  '01/2019': 1584,
#  '02/2019': 1382,
#  '03/2019': 1552,
#  '04/2019': 1554,
#  '05/2019': 1620,
#  '06/2019': 1521,
#  '07/2019': 1679,
#  '08/2019': 1672,
#  '09/2019': 1539,
#  '10/2019': 1598,
#  '11/2019': 1610,
#  '12/2019': 1550,
#  '01/2020': 1564,
#  '02/2020': 1364,
#  '03/2020': 1194,
#  '04/2020': 1098,
#  '05/2020': 1030,
#  '06/2020': 1130,
#  '07/2020': 1358,
#  '08/2020': 1171,
#  '09/2020': 1184,
#  '10/2020': 2043,
#  '11/2020': 2026,
#  '12/2020': 2839,
#  '01/2021': 2517,
#  '02/2021': 1586,
#  '03/2021': 1580,
#  '04/2021': 1147,
#  '05/2021': 1229,
#  '06/2021': 1451,
#  '07/2021': 1281,
#  '08/2021': 1269,
#  '09/2021': 1238,
#  '10/2021': 1170,
#  '11/2021': 1112,
#  '12/2021': 1088,
#  '01/2022': 1113,
#  '02/2022': 898,
#  '03/2022': 1075}

# %% [markdown]
# ### Output the count for each type of crime into excel

# %%
for i in count_domestic:
    with open('type_crime.csv','a') as f:
        wf = csv.writer(f)
        wf.writerow([i,count_domestic[i],count_nondomestic[i],
                     count_persons[i],count_property[i],count_deceptive[i]])

# %% [markdown]
# # Part 2: Conduct the SARIMA for crime data from 2010-2022

# %%
crime_d=pd.DataFrame(list(count_domestic.items()),
                   columns=['Month', 'Count'])
crime_d.index = pd.to_datetime(crime_d['Month'])
crime_d.drop(columns='Month',inplace=True)
crime_d.head()
# Out:
#             Count
# Month
# 2015-01-01   3281
# 2015-02-01   2578
# 2015-03-01   3462
# 2015-04-01   3593
# 2015-05-01   4035

# %%
crime_d.plot()
plt.title('Trend for Domestic Crime (2015-2022)');

# %%
crime_nd=pd.DataFrame(list(count_nondomestic.items()),
                   columns=['Month', 'Count'])
crime_nd.index = pd.to_datetime(crime_nd['Month'])
crime_nd.drop(columns='Month',inplace=True)
crime_nd.head()
# Out:
#             Count
# Month
# 2015-01-01  17664
# 2015-02-01  13821
# 2015-03-01  18220
# 2015-04-01  18134
# 2015-05-01  19673

# %%
crime_nd.plot()
plt.title('Trend for Non-Domestic Crime (2015-2022)');

# %%
crime_person=pd.DataFrame(list(count_persons.items()),
                   columns=['Month', 'Count'])
crime_person.index = pd.to_datetime(crime_person['Month'])
crime_person.drop(columns='Month',inplace=True)
crime_person.head()
# Out:
#             Count
# Month
# 2015-01-01   7135
# 2015-02-01   5825
# 2015-03-01   7889
# 2015-04-01   7799
# 2015-05-01   9088

# %%
crime_person.plot()
plt.title('Trend for Crime Against Persons (2015-2022)');

# %%
crime_property=pd.DataFrame(list(count_property.items()),
                   columns=['Month', 'Count'])
crime_property.index = pd.to_datetime(crime_property['Month'])
crime_property.drop(columns='Month',inplace=True)
crime_property.head()
# Out:
#             Count
# Month
# 2015-01-01   9038
# 2015-02-01   6492
# 2015-03-01   8779
# 2015-04-01   9332
# 2015-05-01  10211

# %%
crime_property.plot()
plt.title('Trend for Crime Against Peoperty (2015-2022)');
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
crime_deceptive=pd.DataFrame(list(count_deceptive.items()),
                   columns=['Month', 'Count'])
crime_deceptive.index = pd.to_datetime(crime_deceptive['Month'])
crime_deceptive.drop(columns='Month',inplace=True)
crime_deceptive.head()
# Out:
#             Count
# Month
# 2015-01-01   1344
# 2015-02-01   1325
# 2015-03-01   1447
# 2015-04-01   1491
# 2015-05-01   1323

# %%
crime_deceptive.plot()
plt.title('Trend for Deceptive Crime (2015-2022)');

# %% [markdown]
# From the above plot, there is a seasonality in the pattern of crime.
# So we firstly try to decompose the seasonal factor to extract the trend.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm

# %%
decompose_dome = seasonal_decompose(crime_d, model="additive")
decompose_dome.plot();

# %%
decompose_nondomestic = seasonal_decompose(crime_nd, model="additive")
decompose_nondomestic.plot();

# %%
decompose_person = seasonal_decompose(crime_person, model="additive")
decompose_person.plot();

# %%
decompose_property = seasonal_decompose(crime_property, model="additive")
decompose_property.plot();

# %%
decompose_deceptive = seasonal_decompose(crime_deceptive, model="additive")
decompose_deceptive.plot();

# %%
# mod = sm.tsa.statespace.SARIMAX(,
#                                 order=(0, 0, 1),
#                                 seasonal_order=(1, 1, 1, 12),
#                                 enforce_stationarity=False,
#                                 enforce_invertibility=False)
# results = mod.fit()
# print(results.summary().tables[1])

# %%
model=sm.tsa.statespace.SARIMAX(crime_d['Count'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
crime_d['forecast']=results.predict(start="2020-01-01",end="2022-01-01",dynamic=True)
crime_d[['Count','forecast']].plot(figsize=(12,8))
plt.title('Prediction for Domestic Crime');
# Out:
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
model=sm.tsa.statespace.SARIMAX(crime_nd['Count'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
crime_nd['forecast']=results.predict(start="2020-01-01",end="2022-01-01",dynamic=True)
crime_nd[['Count','forecast']].plot(figsize=(12,8))
plt.title('Prediction for Non-Domestic Crime');
# Out:
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
model=sm.tsa.statespace.SARIMAX(crime_person['Count'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
crime_person['forecast']=results.predict(start="2020-01-01",end="2022-01-01",dynamic=True)
crime_person[['Count','forecast']].plot(figsize=(12,8))
plt.title('Prediction for Crime Against Persons');
# Out:
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
model=sm.tsa.statespace.SARIMAX(crime_property['Count'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
crime_property['forecast']=results.predict(start="2020-01-01",end="2022-01-01",dynamic=True)
crime_property[['Count','forecast']].plot(figsize=(12,8))
plt.title('Prediction for Crime Against Property');
# Out:
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
model=sm.tsa.statespace.SARIMAX(crime_deceptive['Count'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
crime_deceptive['forecast']=results.predict(start="2020-01-01",end="2022-01-01",dynamic=True)
crime_deceptive[['Count','forecast']].plot(figsize=(12,8))
plt.title('Prediction for Deceptive Crime');
# Out:
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
